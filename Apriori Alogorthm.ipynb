# %% [markdown]
# **OBJECTIVE: TO PERFORM APRIORI ALGORITHM ON A TRANSACTION DATASET**

# %% [markdown]
# Apriori algorithm refers to the algorithm which is used to calculate the association rules between objects. It means how two or more objects are related to one another. The apriori algorithm is an association rule leaning that analyzes that people who bought product A also bought product B.

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import time

# %%
data = pd.read_csv("/Users/prashastisaraf/Downloads/Groceries_dataset-2.csv")
data
# Out:
#     Member_number      Date itemDescription
# 0            1000  27/05/15            soda
# 1            1000  15/03/15      whole milk
# 2            1000  24/06/14      whole milk
# 3            1000  15/03/15          yogurt
# 4            1001  12/12/14      whole milk
# ..            ...       ...             ...
# 57           1014  03/10/15          yogurt
# 58           1014  06/10/14      rolls/buns
# 59           1015  04/05/15    citrus fruit
# 60           1015  04/05/15      whole milk
# 61           1015  28/06/14      rolls/buns
#
# [62 rows x 3 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %%
## Combing all the items in list format for each cutomer

transactions = [a[1]['itemDescription'].tolist() 
                for a in list(data.groupby(['Member_number']))]

# %%
transactions
# Out:
# [['soda', 'whole milk', 'whole milk', 'yogurt'],
#  ['whole milk', 'soda', 'whole milk', 'soda', 'rolls/buns'],
#  ['tropical fruit', 'whole milk', 'other vegetables'],
#  ['root vegetables', 'rolls/buns', 'rolls/buns', 'rolls/buns'],
#  ['other vegetables',
#   'root vegetables',
#   'rolls/buns',
#   'whole milk',
#   'other vegetables',
#   'whole milk',
#   'whole milk',
#   'tropical fruit',
#   'rolls/buns'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whole milk', 'whole milk', 'rolls/buns', 'rolls/buns'],
#  ['tropical fruit', 'soda', 'yogurt', 'root vegetables', 'yogurt'],
#  ['tropical fruit', 'yogurt', 'yogurt'],
#  ['rolls/buns'],
#  ['whole milk', 'citrus fruit', 'other vegetables', 'yogurt', 'rolls/buns'],
#  ['tropical fruit', 'root vegetables', 'yogurt', 'whole milk', 'rolls/buns'],
#  ['whole milk',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk'],
#  ['whole milk', 'whole milk', 'yogurt', 'rolls/buns'],
#  ['citrus fruit', 'whole milk', 'rolls/buns']]

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     citrus fruit  other vegetables  rolls/buns  root vegetables   soda  \
# 0          False             False       False            False   True
# 1          False             False        True            False   True
# 2          False              True       False            False  False
# 3          False             False        True             True  False
# 4          False              True        True             True  False
# 5          False             False        True            False  False
# 6          False             False        True            False  False
# 7          False             False       False             True   True
# 8          False             False       False            False  False
# 9          False             False        True            False  False
# 10          True              True        True            False  False
# 11         False             False        True             True  False
# 12         False              True       False             True  False
# 13         False             False        True            False  False
# 14          True             False        True            False  False
#
#     tropical fruit  whole milk  yogurt
# 0            False        True    True
# 1            False        True   False
# 2             True        True   False
# 3            False       False   False
# 4             True        True   False
# 5            False       False   False
# 6            False        True   False
# 7             True       False    True
# 8             True       False    True
# 9            False       False   False
# 10           False        True    True
# 11            True        True    True
# 12            True        True   False
# 13           False        True    True
# 14           False        True   False

# %% [markdown]
# Here, using TransactionEncoder object, we transform this dataset into a suitable format

# %%
apriori(df, min_support=0.2, use_colnames=True)
# Out:
#      support                                        itemsets
# 0   0.266667                              (other vegetables)
# 1   0.666667                                    (rolls/buns)
# 2   0.333333                               (root vegetables)
# 3   0.200000                                          (soda)
# 4   0.400000                                (tropical fruit)
# 5   0.666667                                    (whole milk)
# 6   0.400000                                        (yogurt)
# 7   0.200000              (tropical fruit, other vegetables)
# 8   0.266667                  (other vegetables, whole milk)
# 9   0.200000                   (root vegetables, rolls/buns)
# 10  0.466667                        (rolls/buns, whole milk)
# 11  0.200000                            (rolls/buns, yogurt)
# 12  0.266667               (root vegetables, tropical fruit)
# 13  0.200000                   (root vegetables, whole milk)
# 14  0.266667                    (tropical fruit, whole milk)
# 15  0.200000                        (tropical fruit, yogurt)
# 16  0.266667                            (whole milk, yogurt)
# 17  0.200000  (tropical fruit, other vegetables, whole milk)
# 18  0.200000                (rolls/buns, whole milk, yogurt)
# 19  0.200000   (root vegetables, whole milk, tropical fruit)

# %% [markdown]
# A minimum support of 0.2 means that we want to find itemsets that appear in at least 20% of the transactions in the dataset.

# %%
frequent_itemsets = apriori(df, min_support = 0.2, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#      support                                        itemsets  length
# 0   0.266667                              (other vegetables)       1
# 1   0.666667                                    (rolls/buns)       1
# 2   0.333333                               (root vegetables)       1
# 3   0.200000                                          (soda)       1
# 4   0.400000                                (tropical fruit)       1
# 5   0.666667                                    (whole milk)       1
# 6   0.400000                                        (yogurt)       1
# 7   0.200000              (tropical fruit, other vegetables)       2
# 8   0.266667                  (other vegetables, whole milk)       2
# 9   0.200000                   (root vegetables, rolls/buns)       2
# 10  0.466667                        (rolls/buns, whole milk)       2
# 11  0.200000                            (rolls/buns, yogurt)       2
# 12  0.266667               (root vegetables, tropical fruit)       2
# 13  0.200000                   (root vegetables, whole milk)       2
# 14  0.266667                    (tropical fruit, whole milk)       2
# 15  0.200000                        (tropical fruit, yogurt)       2
# 16  0.266667                            (whole milk, yogurt)       2
# 17  0.200000  (tropical fruit, other vegetables, whole milk)       3
# 18  0.200000                (rolls/buns, whole milk, yogurt)       3
# 19  0.200000   (root vegetables, whole milk, tropical fruit)       3

# %%
# We are taking item sets with length of 3

frequent_itemsets[(frequent_itemsets['length'] == 3) &
                   (frequent_itemsets['support'] >= 0.2)]

# %% [markdown]
# In association rule mining, once we have identified frequent itemsets using Apriori, we can generate association rules from these frequent itemsets.
# Association rules are in the form of "IF antecedent THEN consequent," and they represent relationships between different items in a transaction.

# %%
rules = association_rules(frequent_itemsets , metric="confidence", min_threshold=0.7)
#rules.head() 
rules
# Out:
#                            antecedents                   consequents  \
# 0                   (other vegetables)              (tropical fruit)
# 1                   (other vegetables)                  (whole milk)
# 2                         (rolls/buns)                  (whole milk)
# 3                         (whole milk)                  (rolls/buns)
# 4                    (root vegetables)              (tropical fruit)
# 5   (tropical fruit, other vegetables)                  (whole milk)
# 6         (tropical fruit, whole milk)            (other vegetables)
# 7       (other vegetables, whole milk)              (tropical fruit)
# 8                   (other vegetables)  (tropical fruit, whole milk)
# 9                 (rolls/buns, yogurt)                  (whole milk)
# 10                (whole milk, yogurt)                  (rolls/buns)
# 11       (root vegetables, whole milk)              (tropical fruit)
# 12   (root vegetables, tropical fruit)                  (whole milk)
# 13        (tropical fruit, whole milk)             (root vegetables)
#
#     antecedent support  consequent support   support  confidence    lift  \
# 0             0.266667            0.400000  0.200000        0.75  1.8750
# 1             0.266667            0.666667  0.266667        1.00  1.5000
# 2             0.666667            0.666667  0.466667        0.70  1.0500
# 3             0.666667            0.666667  0.466667        0.70  1.0500
# 4             0.333333            0.400000  0.266667        0.80  2.0000
# 5             0.200000            0.666667  0.200000        1.00  1.5000
# 6             0.266667            0.266667  0.200000        0.75  2.8125
# 7             0.266667            0.400000  0.200000        0.75  1.8750
# 8             0.266667            0.266667  0.200000        0.75  2.8125
# 9             0.200000            0.666667  0.200000        1.00  1.5000
# 10            0.266667            0.666667  0.200000        0.75  1.1250
# 11            0.200000            0.400000  0.200000        1.00  2.5000
# 12            0.266667            0.666667  0.200000        0.75  1.1250
# 13            0.266667            0.333333  0.200000        0.75  2.2500
#
#     leverage  conviction
# 0   0.093333    2.400000
# 1   0.088889         inf
# 2   0.022222    1.111111
# 3   0.022222    1.111111
# 4   0.133333    3.000000
# 5   0.066667         inf
# 6   0.128889    2.933333
# 7   0.093333    2.400000
# 8   0.128889    2.933333
# 9   0.066667         inf
# 10  0.022222    1.333333
# 11  0.120000         inf
# 12  0.022222    1.333333
# 13  0.111111    2.666667

# %% [markdown]
# The confidence of a consequent event given an antecedent event can be described by using conditional probability. Simply put, it is the probability of event A happening given that event B has already happened.

# %% [markdown]
# Lift measures how likely an item is purchased when another item is purchased, while controlling for how popular both items are. For any value higher than 1, lift shows that there is actually an association. The higher the value, the higher the association. As all the above pair of items have lift greater than 1 they have high association between them
